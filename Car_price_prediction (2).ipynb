# %% [markdown]
# # CAR PRICE PRIDICTION

# %% [markdown]
# # SCRAPPING THE DATA

# %%
#importing releted libraries

import selenium
import pandas as pd 
from selenium import webdriver
import warnings 
warnings.filterwarnings("ignore")
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#connecting driver

driver=webdriver.Chrome(r"C:\Users\ACER\Downloads\chromedriver_win32\chromedriver.exe")
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="260bb66f2e3659378fc0b5f545831569")>

# %%
driver.get("https://www.carwale.com/used/cars-for-sale/?utm_medium=cpc&utm_source=google-perfmax&utm_campaign=16528006254&utm_term=&seller=1&gclid=CjwKCAjw5P2aBhAlEiwAAdY7dBqRh2l3yW9FQ9aCce4XNj_8z1eVaxzkKQo026EIxrB9d51wG_QZyRoCB5MQAvD_BwE#city=10&pc=10&seller=1&sc=-1&so=-1&pn=1")

# %%
model=[]

for i in driver.find_elements(By.XPATH,'//span[@class="spancarname card-detail-block__title-text-with-year"]'):
    model.append(i.text.split()[0])
    
model
# Out:
# ['Volkswagen',
#  'Hyundai',
#  'Volkswagen',
#  'Mahindra',
#  'Skoda',
#  'Mercedes-Benz',
#  'Ford',
#  'Volkswagen',
#  'Maruti',
#  'Maruti',
#  'Honda',
#  'Hyundai',
#  'Hyundai',
#  'Renault',
#  'Honda',
#  'Maruti',
#  'Volkswagen',
#  'Hyundai',
#  'Honda',
#  'Mahindra',
#  'Maruti',
#  'Maruti',
#  'Mercedes-Benz',
#  'Toyota',
#  'Volkswagen',
#  'Toyota',
#  'Honda',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Ford',
#  'Maruti',
#  'Mercedes-Benz',
#  'Mercedes-Benz',
#  'Honda',
#  'Audi',
#  'Hyundai',
#  'Ford',
#  'Mahindra',
#  'BMW',
#  'Hyundai',
#  'Audi',
#  'BMW',
#  'Bentley',
#  'Mercedes-Benz',
#  'Mercedes-Benz',
#  'Mercedes-Benz',
#  'Land',
#  'MINI',
#  'Mercedes-Benz',
#  'BMW',
#  'Land',
#  'BMW',
#  'Mahindra',
#  'Jaguar',
#  'Lexus',
#  'Porsche',
#  'Mercedes-Benz',
#  'Mercedes-Benz',
#  'Mercedes-Benz',
#  'Land',
#  'Mercedes-Benz',
#  'BMW',
#  'Mercedes-Benz',
#  'Mercedes-Benz',
#  'BMW',
#  'Mercedes-Benz',
#  'Audi',
#  'BMW',
# ...

# %%
len(model)
# Out:
# 248

# %%
year=[]

for i in driver.find_elements(By.XPATH,'//span[@class="slYear card-detail-block__title-text-with-year"]'):
    year.append(i.text)
    
year
# Out:
# ['2015',
#  '2014',
#  '2016',
#  '2018',
#  '2016',
#  '2019',
#  '2018',
#  '2021',
#  '2015',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2015',
#  '2017',
#  '2015',
#  '2016',
#  '2015',
#  '2017',
#  '2018',
#  '2015',
#  '2015',
#  '2009',
#  '2013',
#  '2021',
#  '2014',
#  '2017',
#  '2014',
#  '2013',
#  '2015',
#  '2019',
#  '2016',
#  '2017',
#  '2018',
#  '2014',
#  '2014',
#  '2018',
#  '2020',
#  '2018',
#  '2014',
#  '2011',
#  '2022',
#  '2008',
#  '2022',
#  '2021',
#  '2019',
#  '2020',
#  '2020',
#  '2015',
#  '2019',
#  '2021',
#  '2018',
#  '2017',
#  '2019',
#  '2018',
#  '2018',
#  '2021',
#  '2017',
#  '2017',
#  '2018',
#  '2018',
#  '2022',
#  '2017',
#  '2020',
#  '2018',
#  '2021',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2020',
#  '2019',
#  '2021',
#  '2017',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2017',
#  '2020',
#  '2018',
#  '2018',
#  '2021',
#  '2017',
#  '2018',
#  '2017',
#  '2017',
#  '2020',
# ...

# %%
len(year)
# Out:
# 248

# %%
km=[]

for i in driver.find_elements(By.XPATH,'//span[@class="slkms"]'):
    km.append(i.text.split()[0])
    
km
# Out:
# ['50,000',
#  '62,224',
#  '51,372',
#  '27,059',
#  '77,000',
#  '25,000',
#  '93,000',
#  '6,628',
#  '26,315',
#  '61,472',
#  '87,367',
#  '45,876',
#  '35,018',
#  '16,265',
#  '49,769',
#  '48,502',
#  '90,826',
#  '29,448',
#  '56,000',
#  '74,600',
#  '64,300',
#  '55,000',
#  '76,345',
#  '86,000',
#  '82,200',
#  '49,700',
#  '55,200',
#  '23,000',
#  '89,000',
#  '41,700',
#  '68,000',
#  '48,000',
#  '44,392',
#  '65,000',
#  '22,000',
#  '57,108',
#  '62,224',
#  '93,000',
#  '32,467',
#  '40,000',
#  '58,000',
#  '76,000',
#  '8,000',
#  '18,500',
#  '16,500',
#  '950',
#  '31,000',
#  '33,500',
#  '15,000',
#  '43,500',
#  '17,000',
#  '25,500',
#  '15,000',
#  '82,000',
#  '43,000',
#  '40,000',
#  '30,000',
#  '17,000',
#  '39,000',
#  '43,000',
#  '46,000',
#  '30,000',
#  '13,000',
#  '33,000',
#  '32,000',
#  '45,000',
#  '13,000',
#  '40,000',
#  '47,000',
#  '27,000',
#  '47,000',
#  '26,000',
#  '59,000',
#  '18,000',
#  '45,000',
#  '29,000',
#  '11,000',
# ...

# %%
fuel=[]

for i in driver.find_elements(By.XPATH,'//span[@class="fuel"]'):
    fuel.append(i.text)
    
fuel
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
# ...

# %%
city=[]

for i in driver.find_elements(By.XPATH,'//span[@class="cityName"]'):
    city.append(i.text)
    
city
# Out:
# ['Delhi',
#  'Faridabad',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Faridabad',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Faridabad',
#  'Faridabad',
#  'Delhi',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Noida',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Gurgaon',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Gurgaon',
#  'Gurgaon',
#  'Delhi',
#  'Faridabad',
#  'Faridabad',
#  'Delhi',
#  'Faridabad',
#  'Faridabad',
#  'Faridabad',
#  'Faridabad',
#  'Faridabad',
#  'Delhi',
#  'Faridabad',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
car_price=[]

for i in driver.find_elements(By.XPATH,'//span[@class="rupee-lac slprice"]'):
    car_price.append(i.text.split()[1])
    
car_price
# Out:
# ['5.15',
#  '5.35',
#  '4.75',
#  '7.5',
#  '17.5',
#  '41',
#  '25',
#  '5.82',
#  '4.24',
#  '6.5',
#  '6.5',
#  '5.2',
#  '4.85',
#  '2.65',
#  '5.95',
#  '4',
#  '4.9',
#  '4.35',
#  '4.5',
#  '6.15',
#  '5.35',
#  '4.25',
#  '26.85',
#  '2.45',
#  '3.35',
#  '7.3',
#  '3',
#  '3.6',
#  '3.4',
#  '2.7',
#  '4.9',
#  '10.25',
#  '20',
#  '60',
#  '10.25',
#  '13.8',
#  '5.35',
#  '25',
#  '17.4',
#  '27',
#  '4.5',
#  '20',
#  '1.18',
#  '48.5',
#  '78',
#  '1.38',
#  '51',
#  '60',
#  '39.5',
#  '44.95',
#  '1.09',
#  '1.25',
#  '48',
#  '10.75',
#  '52',
#  '49.9',
#  '82.9',
#  '1.35',
#  '43.5',
#  '44',
#  '1.65',
#  '46.5',
#  '43',
#  '44.75',
#  '56.5',
#  '54.5',
#  '74.75',
#  '63',
#  '65',
#  '25.75',
#  '1.52',
#  '59.9',
#  '53.5',
#  '68.5',
#  '27.75',
#  '83',
#  '64.5',
#  '46',
#  '74',
#  '42',
#  '44.75',
#  '56.5',
#  '54.5',
#  '82.9',
#  '1.35',
#  '43.5',
#  '1.65',
#  '65',
#  '25.75',
#  '59.9',
#  '53.5',
#  '46.5',
#  '43',
#  '1.52',
#  '44',
# ...

# %%
len(car_price)
# Out:
# 248

# %%
car_data=pd.DataFrame({"MODEL":model,"YEAR":year,"KM":km,"FUEL":fuel,"CITY":city,"CAR_PRICE":car_price})

# %%
car_data
# Out:
#              MODEL  YEAR      KM    FUEL       CITY CAR_PRICE
# 0       Volkswagen  2015  50,000  Petrol      Delhi      5.15
# 1          Hyundai  2014  62,224  Petrol  Faridabad      5.35
# 2       Volkswagen  2016  51,372  Petrol      Delhi      4.75
# 3         Mahindra  2018  27,059  Diesel      Delhi       7.5
# 4            Skoda  2016  77,000  Petrol      Delhi      17.5
# ..             ...   ...     ...     ...        ...       ...
# 243          Volvo  2018  20,000  Diesel      Delhi     44.75
# 244            BMW  2017  32,000  Diesel      Delhi     29.25
# 245         Toyota  2020  55,000  Diesel      Delhi     38.75
# 246           Ford  2017  70,000  Diesel      Delhi      24.6
# 247  Mercedes-Benz  2017  20,000  Diesel      Delhi      74.5
#
# [248 rows x 6 columns]

# %%
driver2=webdriver.Chrome(r"C:\Users\ACER\Downloads\chromedriver_win32\chromedriver.exe")
driver2
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="3fc8b124d3f633e23ee0cf7eb4e70863")>

# %%
driver2.get("https://www.olx.in/en-in/delhi_g2001152/cars_c84")

# %%
model2=[]

for i in driver2.find_elements(By.XPATH,'//div[@class="_2Gr10"]'):
    model2.append(i.text.split()[0])
    
model2
# Out:
# ['Ford',
#  'Maruti',
#  'Maruti',
#  'Honda',
#  'Toyota',
#  'Hyundai',
#  'Maruti',
#  'Mercedes-Benz',
#  'Maruti',
#  'Hyundai',
#  'Maruti',
#  'Honda',
#  'Maruti',
#  'Audi',
#  'Hyundai',
#  'Volvo',
#  'Maruti',
#  'Maruti',
#  'Honda',
#  'Hyundai',
#  'Maruti',
#  'Toyota',
#  'Honda',
#  'Ford',
#  'Maruti',
#  'Hyundai',
#  'Tata',
#  'Maruti',
#  'Honda',
#  'Mahindra',
#  'Ford',
#  'Maruti',
#  'Mercedes',
#  'Land',
#  'Hyundai',
#  'Maruti',
#  'Mahindra',
#  'Toyota',
#  'Audi',
#  'Volvo',
#  'Maruti',
#  'Maruti',
#  'Honda',
#  'Volkswagen',
#  'Land',
#  'Maruti',
#  'Hyundai',
#  'Hyundai',
#  'Chevrolet',
#  'Mahindra',
#  'Toyota',
#  'Hyundai',
#  'Jaguar',
#  'Mahindra',
#  'Mercedes-Benz',
#  'Hyundai',
#  'Maruti',
#  'Hyundai',
#  'Skoda',
#  'Maruti',
#  'Toyota',
#  'Porsche',
#  'Hyundai',
#  'Hyundai',
#  'Ford',
#  'Honda',
#  'Renault',
#  'Nissan',
#  'Hyundai',
#  'Maruti',
#  'Land',
#  'Maruti',
#  'Hyundai',
#  'Toyota',
#  'Toyota',
# ...

# %%
len(model2)
# Out:
# 493

# %%
year2=[]

for i in driver2.find_elements(By.XPATH,'//div[@class="_21gnE"]'):
    year2.append(i.text.split()[0])
    
year2
# Out:
# ['2015',
#  '2020',
#  '2021',
#  '2010',
#  '2015',
#  '2021',
#  '2016',
#  '2018',
#  '2021',
#  '2012',
#  '2016',
#  '2010',
#  '2020',
#  '2015',
#  '2018',
#  '2017',
#  '2009',
#  '2013',
#  '2019',
#  '2017',
#  '2021',
#  '2013',
#  '2009',
#  '2015',
#  '2016',
#  '2016',
#  '2019',
#  '2017',
#  '2017',
#  '2015',
#  '2015',
#  '2021',
#  '2009',
#  '2018',
#  '2013',
#  '2020',
#  '2022',
#  '2013',
#  '2013',
#  '2020',
#  '2017',
#  '2017',
#  '2010',
#  '2017',
#  '2012',
#  '2014',
#  '2013',
#  '2019',
#  '2010',
#  '2013',
#  '2014',
#  '2015',
#  '2013',
#  '2014',
#  '2017',
#  '2009',
#  '2019',
#  '2013',
#  '2013',
#  '2017',
#  '2021',
#  '2021',
#  '2017',
#  '2010',
#  '2013',
#  '2014',
#  '2013',
#  '2013',
#  '2020',
#  '2020',
#  '2022',
#  '2013',
#  '2017',
#  '2016',
#  '2009',
#  '2022',
#  '2022',
#  '2021',
#  '2022',
#  '2017',
#  '2015',
#  '2019',
#  '2018',
#  '2010',
#  '2022',
#  '2022',
#  '2022',
#  '2017',
#  '2022',
#  '2022',
# ...

# %%
len(year2)
# Out:
# 493

# %%
km2=[]

for i in driver2.find_elements(By.XPATH,'//div[@class="_21gnE"]'):
    km2.append(i.text.split()[2])
    
km2
# Out:
# ['74000.0',
#  '19,059',
#  '34,000',
#  '160,000',
#  '70,000',
#  '17,000',
#  '64,000',
#  '16,000',
#  '3,500',
#  '48,000',
#  '45,000',
#  '62000.0',
#  '62,000',
#  '88,000',
#  '24,300',
#  '26,000',
#  '65,000',
#  '45,000',
#  '37000.0',
#  '38,959',
#  '17,000',
#  '120,000',
#  '90,000',
#  '50,000',
#  '90,000',
#  '67,000',
#  '37000.0',
#  '77,000',
#  '77000.0',
#  '56,000',
#  '58,000',
#  '18,000',
#  '56000.0',
#  '27000.0',
#  '63,000',
#  '26,000',
#  '18,000',
#  '90,000',
#  '45,000',
#  '26000.0',
#  '21,316',
#  '33606.0',
#  '120,000',
#  '28,546',
#  '52,000',
#  '61000.0',
#  '68000.0',
#  '47000.0',
#  '57,000',
#  '70000.0',
#  '97859.0',
#  '61000.0',
#  '70000.0',
#  '950,745',
#  '58,000',
#  '66,000',
#  '45,000',
#  '62,000',
#  '71,000',
#  '21,316',
#  '27400.0',
#  '20,000',
#  '50,000',
#  '50,000',
#  '100,000',
#  '62,000',
#  '81,598',
#  '65000.0',
#  '14000.0',
#  '37,000',
#  '30,000',
#  '72000.0',
#  '68,000',
#  '112000.0',
# ...

# %%
len(km2)
# Out:
# 493

# %%
city2=[]

for i in driver2.find_elements(By.XPATH,'//div[@class="_3VRSm"]'):
    city2.append(i.text.split()[0])
    
city2
# Out:
# ['Kirti',
#  'Jagatpuri',
#  'Mayur',
#  'Rohini',
#  'Bhuli',
#  'Rajouri',
#  'Dhaula',
#  'Hauz',
#  'Raja',
#  'Karol',
#  'Dilshad',
#  'Jhandewalan',
#  'Rajouri',
#  'Defence',
#  'Amar',
#  'Tagore',
#  'Saket',
#  'Saket',
#  'Badarpur',
#  'Yadav',
#  'Ashok',
#  'Greater',
#  'Dwarka',
#  'Chattarpur',
#  'Vasant',
#  'Ramesh',
#  'Preet',
#  'Nirman',
#  'Nirman',
#  'Nirman',
#  'Nirman',
#  'Nirman',
#  'Moti',
#  'Okhla',
#  'Karol',
#  'Rajouri',
#  'Patel',
#  'Patel',
#  'Rajouri',
#  'Ashok',
#  'Pitampura',
#  'Vikaspuri',
#  'Chander',
#  'Rohini',
#  'South',
#  'Jangpura',
#  'Peera',
#  'Rohini',
#  'Peera',
#  'Peera',
#  'Karol',
#  'Preet',
#  'Punjabi',
#  'Sanjay',
#  'Naraina',
#  'Pitampura',
#  'Rohini',
#  'Rajouri',
#  'New',
#  'Sarita',
#  'Jangpura',
#  'Vikaspuri',
#  'Mayur',
#  'Pant',
#  'Dilshad',
#  'Rajouri',
#  'Mayur',
#  'Jhandewalan',
#  'Dayanand',
#  'Rohini',
#  'Lajpat',
#  'Saket',
#  'Lajpat',
#  'Saket',
#  'Jhilmil',
# ...

# %%
len(city2)
# Out:
# 493

# %%
car_price2=[]

for i in driver2.find_elements(By.XPATH,'//span[@class="_1zgtX"]'):
    car_price2.append(i.text.split()[1])
    
car_price2
# Out:
# ['4,50,000',
#  '5,48,146',
#  '6,45,000',
#  '2,15,000',
#  '16,90,000',
#  '18,90,000',
#  '4,80,000',
#  '47,00,000',
#  '8,35,000',
#  '2,25,000',
#  '5,25,000',
#  '2,60,000',
#  '10,99,000',
#  '13,75,000',
#  '11,79,000',
#  '34,75,000',
#  '1,80,000',
#  '2,25,000',
#  '6,40,000',
#  '8,80,446',
#  '11,90,000',
#  '11,70,000',
#  '2,85,000',
#  '4,90,000',
#  '3,90,000',
#  '5,40,000',
#  '8,40,000',
#  '4,10,000',
#  '10,15,000',
#  '6,25,000',
#  '5,10,000',
#  '12,00,000',
#  '4,95,000',
#  '41,50,000',
#  '4,90,000',
#  '6,45,000',
#  '15,90,000',
#  '11,50,000',
#  '12,75,000',
#  '61,00,000',
#  '5,97,200',
#  '3,53,359',
#  '2,00,000',
#  '5,25,000',
#  '27,90,000',
#  '4,49,999',
#  '4,25,000',
#  '10,25,000',
#  '1,40,000',
#  '2,65,000',
#  '6,70,000',
#  '4,40,000',
#  '12,90,000',
#  '1,76,999',
#  '39,00,000',
#  '1,10,000',
#  '8,50,000',
#  '2,10,000',
#  '4,95,000',
#  '5,60,000',
#  '8,99,999',
#  '82,00,000',
#  '8,30,000',
#  '1,34,500',
#  '2,20,000',
# ...

# %%
car_data=pd.DataFrame({"MODEL":model,"YEAR":year,"KM":km,"CITY":city,"CAR_PRICE":car_price})

# %%
car_data
# Out:
#              MODEL  YEAR      KM       CITY CAR_PRICE
# 0       Volkswagen  2015  50,000      Delhi      5.15
# 1          Hyundai  2014  62,224  Faridabad      5.35
# 2       Volkswagen  2016  51,372      Delhi      4.75
# 3         Mahindra  2018  27,059      Delhi       7.5
# 4            Skoda  2016  77,000      Delhi      17.5
# ..             ...   ...     ...        ...       ...
# 243          Volvo  2018  20,000      Delhi     44.75
# 244            BMW  2017  32,000      Delhi     29.25
# 245         Toyota  2020  55,000      Delhi     38.75
# 246           Ford  2017  70,000      Delhi      24.6
# 247  Mercedes-Benz  2017  20,000      Delhi      74.5
#
# [248 rows x 5 columns]

# %%
car_data2=pd.DataFrame({"MODEL":model2,"YEAR":year2,"KM":km2,"CITY":city2,"CAR_PRICE":car_price2})

# %%
car_data2
# Out:
#              MODEL  YEAR       KM       CITY  CAR_PRICE
# 0             Ford  2015  74000.0      Kirti   4,50,000
# 1           Maruti  2020   19,059  Jagatpuri   5,48,146
# 2           Maruti  2021   34,000      Mayur   6,45,000
# 3            Honda  2010  160,000     Rohini   2,15,000
# 4           Toyota  2015   70,000      Bhuli  16,90,000
# ..             ...   ...      ...        ...        ...
# 488        Hyundai  2019   35,000    Subhash   5,85,000
# 489  Mercedes-Benz  2015  53000.0     Sainik  20,90,000
# 490       Mahindra  2015   57,000     Lajpat   8,15,000
# 491        Hyundai  2016   18,000     Lajpat   6,35,000
# 492        Hyundai  2019  57800.0     Lajpat  13,95,000
#
# [493 rows x 5 columns]

# %%
df=[car_data,car_data2]

# %%
cr=pd.concat(df)
display(cr)
# Out:
#              MODEL  YEAR       KM       CITY  CAR_PRICE
# 0       Volkswagen  2015   50,000      Delhi       5.15
# 1          Hyundai  2014   62,224  Faridabad       5.35
# 2       Volkswagen  2016   51,372      Delhi       4.75
# 3         Mahindra  2018   27,059      Delhi        7.5
# 4            Skoda  2016   77,000      Delhi       17.5
# ..             ...   ...      ...        ...        ...
# 488        Hyundai  2019   35,000    Subhash   5,85,000
# 489  Mercedes-Benz  2015  53000.0     Sainik  20,90,000
# 490       Mahindra  2015   57,000     Lajpat   8,15,000
# 491        Hyundai  2016   18,000     Lajpat   6,35,000
# 492        Hyundai  2019  57800.0     Lajpat  13,95,000
#
# [741 rows x 5 columns]

# %% [markdown]
# # PREDICTION OF CAR PRICE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
cr
# Out:
#              MODEL  YEAR       KM       CITY  CAR_PRICE
# 0       Volkswagen  2015   50,000      Delhi       5.15
# 1          Hyundai  2014   62,224  Faridabad       5.35
# 2       Volkswagen  2016   51,372      Delhi       4.75
# 3         Mahindra  2018   27,059      Delhi        7.5
# 4            Skoda  2016   77,000      Delhi       17.5
# ..             ...   ...      ...        ...        ...
# 488        Hyundai  2019   35,000    Subhash   5,85,000
# 489  Mercedes-Benz  2015  53000.0     Sainik  20,90,000
# 490       Mahindra  2015   57,000     Lajpat   8,15,000
# 491        Hyundai  2016   18,000     Lajpat   6,35,000
# 492        Hyundai  2019  57800.0     Lajpat  13,95,000
#
# [741 rows x 5 columns]

# %% [markdown]
# 741 rows and 5 columns in car Dataset.

# %%
cr.head()
# Out:
#         MODEL  YEAR      KM       CITY CAR_PRICE
# 0  Volkswagen  2015  50,000      Delhi      5.15
# 1     Hyundai  2014  62,224  Faridabad      5.35
# 2  Volkswagen  2016  51,372      Delhi      4.75
# 3    Mahindra  2018  27,059      Delhi       7.5
# 4       Skoda  2016  77,000      Delhi      17.5

# %% [markdown]
# First five rows.

# %%
cr.tail()
# Out:
#              MODEL  YEAR       KM     CITY  CAR_PRICE
# 488        Hyundai  2019   35,000  Subhash   5,85,000
# 489  Mercedes-Benz  2015  53000.0   Sainik  20,90,000
# 490       Mahindra  2015   57,000   Lajpat   8,15,000
# 491        Hyundai  2016   18,000   Lajpat   6,35,000
# 492        Hyundai  2019  57800.0   Lajpat  13,95,000

# %% [markdown]
# last five rows.

# %%
cr.sample(3)
# Out:
#       MODEL  YEAR       KM    CITY  CAR_PRICE
# 345  Jaguar  2018   58,000  Dwarka  29,00,000
# 485   Volvo  2017  118,000    Pusa  46,00,000
# 269   Skoda  2022        1   Kirti  17,99,000

# %% [markdown]
# Random three data.

# %%
cr.keys()
# Out:
# Index(['MODEL', 'YEAR', 'KM', 'CITY', 'CAR_PRICE'], dtype='object')

# %%
cr.dtypes
# Out:
# MODEL        object
# YEAR         object
# KM           object
# CITY         object
# CAR_PRICE    object
# dtype: object

# %% [markdown]
# All columns has object data types.

# %%
cr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 741 entries, 0 to 492
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MODEL      741 non-null    object
#  1   YEAR       741 non-null    object
#  2   KM         741 non-null    object
#  3   CITY       741 non-null    object
#  4   CAR_PRICE  741 non-null    object
# dtypes: object(5)
# memory usage: 34.7+ KB

# %% [markdown]
# There is no null values in Car dataset.

# %% [markdown]
# # CHECKING NULL VALUES

# %%
cr.isnull().sum()
# Out:
# MODEL        0
# YEAR         0
# KM           0
# CITY         0
# CAR_PRICE    0
# dtype: int64

# %%
sns.heatmap(cr.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# No Null values in car_data Dataset.

# %% [markdown]
# # Statistical Summary

# %%
cr.describe()
# Out:
#          MODEL  YEAR      KM   CITY CAR_PRICE
# count      741   741     741    741       741
# unique      30    16     309    117       475
# top     Maruti  2017  70,000  Delhi  5,25,000
# freq       152    91      20    189        12

# %% [markdown]
# # DATA VISUALIZATION OR EDA

# %%
cr.head(2)
# Out:
#         MODEL  YEAR      KM       CITY CAR_PRICE
# 0  Volkswagen  2015  50,000      Delhi      5.15
# 1     Hyundai  2014  62,224  Faridabad      5.35

# %%
cr["MODEL"].value_counts()
# Out:
# Maruti           152
# Hyundai          120
# Mercedes-Benz    104
# Audi              43
# Honda             41
# Toyota            41
# BMW               37
# Mahindra          35
# Ford              29
# Skoda             15
# Renault           15
# Porsche           15
# Volvo             14
# Land              14
# Volkswagen        13
# Jaguar            11
# MG                 7
# MINI               6
# Tata               6
# Bentley            5
# Kia                5
# Jeep               3
# Chevrolet          2
# Fiat               2
# Lexus              1
# Isuzu              1
# Mercedes           1
# Nissan             1
# Mitsubishi         1
# Mini               1
# Name: MODEL, dtype: int64

# %% [markdown]
# Sale of Maruti, Hyundai and Mercedes-Benz type are higher.

# %%
cr["YEAR"].value_counts()
# Out:
# 2017    91
# 2018    82
# 2015    71
# 2021    66
# 2013    66
# 2014    65
# 2020    63
# 2019    53
# 2016    44
# 2022    40
# 2012    27
# 2010    26
# 2011    20
# 2009    17
# 2008     9
# 2007     1
# Name: YEAR, dtype: int64

# %%
sns.scatterplot(cr["YEAR"])
# Out:
# <AxesSubplot: ylabel='YEAR'>

# %% [markdown]
# Sales are higher after 2013 year.

# %%
cr["KM"].value_counts()
# Out:
# 70,000      20
# 45,000      17
# 1           15
# 20,000      14
# 30,000      13
#             ..
# 112000.0     1
# 45,876       1
# 10           1
# 87,367       1
# 57800.0      1
# Name: KM, Length: 309, dtype: int64

# %% [markdown]
# Diesel and petrol both type of Fuel are the most.

# %%
cr["CITY"].value_counts()
# Out:
# Delhi         189
# Kirti          32
# Karol          28
# Rajouri        27
# Rohini         27
#              ...
# Viswakarma      1
# Inderlok        1
# Bhuli           1
# Peshwa          1
# Sainik          1
# Name: CITY, Length: 117, dtype: int64

# %%
sns.catplot(cr["CITY"],height=15)

# %% [markdown]
# Sales are higher in Delhi City.

# %%
cr["CAR_PRICE"].value_counts()
# Out:
# 5,25,000     12
# 4,50,000      7
# 3,25,000      7
# 4,25,000      6
# 2,95,000      6
#              ..
# 10,99,000     1
# 47,00,000     1
# 2,15,000      1
# 16.5          1
# 13,95,000     1
# Name: CAR_PRICE, Length: 475, dtype: int64
